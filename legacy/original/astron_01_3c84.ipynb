# %% [markdown]
# <h3>artools: track(source,epoch,dt,N,PRESSURE,TEMPERATURE,RELATIVE_HUMIDITY)
# </h3>
# tracking di una sorgente radio astronomica

# %%
import sys
import matplotlib.pyplot as plt
from artools import track, savetrack2

# %%
#source='W3(OH)'
source='3c84'
epoch = 'NOW'
#epoch = '2025-05-07 06:00:00'
dt=600
N=120

PRESSURE=940
TEMPERATURE=17
RELATIVE_HUMIDITY = 69
t,mjd,az,el=track(source,epoch,dt,N,PRESSURE,TEMPERATURE,RELATIVE_HUMIDITY)

# se pressione, umidità e temperatura non sono definite la correzione dell'indice di rifrazione non viene applicata
#t,mjd,az,el=track(source,epoch,dt,N)

# %%
savetrack2('test2.txt',mjd,az,el)
